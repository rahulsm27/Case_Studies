# %%
"""
https://write.geeksforgeeks.org/post/5450187
"""

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"""
to find the solution to the constrained optimization problem, we typically set the gradient of the Lagrange function with respect to the decision variables (x) and the Lagrange multipliers (λ and μ) to zero and solve the resulting system of equations. This approach is known as the Karush-Kuhn-Tucker (KKT) conditions, and it helps identify the optimal solution that satisfies the constraints

This method has number of disadvantages.

KKT conditions are a in general a system of nonlinear equation and inequalities in themselves. So obtaining a solution is not easy baring some special cases such as quadratic programming
Morever KKT condiatoon are only necessary in case of 'non linear non convex 'optimization. They become sufficient only in case of 'linear' or 'non linear convex' optimization. Since majority of problems are non linear and non conves this means point satifying KKT condition may or may not be a point of optimality.
"""

"""

# %% [markdown]
# ![image.png](attachment:image.png)
