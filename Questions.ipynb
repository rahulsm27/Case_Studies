# %%
# Q1 

"""
If you were to build a Netflix clone, how would you build a system that predicts when a user stops watching a TV show, whether they are tired of that show or they’re just taking a break

"""

# %%
"""
Data Collection:

User Activity: Capture user interactions, such as play, pause, stop, skip, rewind, etc. 

Content Metadata: Information about the show, like genre, director, cast, episode duration, ratings, average duration watched.

User Profile: Historical watching patterns, user demographics, device types, preferences, etc. 

Temporal Data: Time of day, weekday vs. weekend, holidays, etc. 

External Factors: Events or news related to a show, like a new season release, controversies, etc. Feature Engineering:

Session duration: How long a user watches in one sitting. 
Episode completion: Whether users tend to complete episodes or drop off at specific points. 

Binge patterns: How frequently a user watches episodes back-to-back. 

Time since last watch: Duration since the user last watched the show. 

User feedback: Ratings, reviews, likes/dislikes for episodes. Search patterns: How often users search for the show or its related content. Exploratory Data Analysis (EDA):

Identify patterns of drop-offs for different shows. Understand user segments (e.g., binge-watchers vs. occasional viewers). Identify correlation between content metadata and watching patterns.




Model Building:

Binary Classification: Define the problem as predicting a binary outcome: "tired of show" (1) or "taking a break" (0). Model Selection: Experiment with various algorithms like Random Forest, Gradient Boosting, Neural Networks, etc. Training & Validation: 

Split data into training and validation sets to train and tune the model. Regularly validate using techniques like cross-validation. Feature Importance & Interpretation:

Understand which features are the most predictive. 


"""

# %%
# Q2
# How would you build a 'restaurants you may like' recommender system on the news feed?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Approach one : Using Correlation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# APproach two Using Matrix Factorization

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Content-based filtering is suitable for providing personalized recommendations that match user preferences and interests, while collaborative filtering can provide surprising and diverse recommendations that expose users to new or popular items.
    
    The choice is simple: Use collaborative filtering when you want to be predictive. Use content filtering when you don't have interaction signals (cold-start) or as a pure discovery tool ("you viewed a pink shirt but didn't buy it, so here are other pink shirts to help you find the right one"). Content filtering is backward looking and does not usually translate well to new sessions by definition.


The 'Restaurants you may like' recommender system is adopted using two methods:

Content-Based Filtering (CBF):
Definition: It models users' tastes based on their past behaviors but does not benefit from data on other users.

Limitation of this method:

Novelty in recommended results because it only looks at the user's history and never jumps to other areas that users might like but haven't interacted with before.
If the quality of content does not contain enough information to discriminate the items precisely, CBF will perform poorly.
Collaborative Filtering (CF):
Definition: CF looks at user/item interactions (visits) and tries to find similarities among users or items to do the recommender job.

Limitations:

Sparse interaction matrix between users and items: where many users have very few or even no interactions.
Cold Start Problem: It is a huge problem to find suitable restaurants, especially for newcomers to specific areas.
To solve the limitations of both methods, a hybrid approach is used, which leverages the collaborative information between users, items, and metadata to complete the recommendation job.
